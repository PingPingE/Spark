# %% [markdown]
# # 데이터 전처리 및 피처 엔지니어링

# %%
root= '/FileStore/tables/bin'
retail = root+'/retail-data/by-day/*.csv'
simple_ml_int = root+'/simple-ml-integers'
simple_ml = root+'/simple-ml'
simple_ml_scale = root+'/simple-ml-scaling'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sales = spark.read.format('csv')\
.option('header', 'true')\
.option('inferSchema', 'true')\
.load(retail)\
.coalesce(5)\
.where("Description is not null")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fakeIntDF = spark.read.parquet(simple_ml_int)
simpleDF = spark.read.format('json').load(simple_ml)
scaleDF = spark.read.parquet(simple_ml_scale)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(fakeIntDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>int1</th><th>int2</th><th>int3</th></tr></thead><tbody><tr><td>1</td><td>2</td><td>3</td></tr><tr><td>4</td><td>5</td><td>6</td></tr><tr><td>7</td><td>8</td><td>9</td></tr></tbody></table></div>

# %%
display(simpleDF.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>lab</th><th>value1</th><th>value2</th></tr></thead><tbody><tr><td>green</td><td>good</td><td>1</td><td>14.386294994851129</td></tr><tr><td>blue</td><td>bad</td><td>8</td><td>14.386294994851129</td></tr><tr><td>blue</td><td>bad</td><td>12</td><td>14.386294994851129</td></tr><tr><td>green</td><td>good</td><td>15</td><td>38.97187133755819</td></tr><tr><td>green</td><td>good</td><td>12</td><td>14.386294994851129</td></tr><tr><td>green</td><td>bad</td><td>16</td><td>14.386294994851129</td></tr><tr><td>red</td><td>good</td><td>35</td><td>14.386294994851129</td></tr><tr><td>red</td><td>bad</td><td>1</td><td>38.97187133755819</td></tr><tr><td>red</td><td>bad</td><td>2</td><td>14.386294994851129</td></tr><tr><td>red</td><td>bad</td><td>16</td><td>14.386294994851129</td></tr></tbody></table></div>

# %%
display(scaleDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td></tr></tbody></table></div>

# %%
sales.cache()
display(sales.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>Quantity</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th></tr></thead><tbody><tr><td>579256</td><td>20973</td><td>12 PENCIL SMALL TUBE WOODLAND</td><td>24</td><td>2011-11-29 08:07:00</td><td>0.65</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>21891</td><td>TRADITIONAL WOODEN SKIPPING ROPE</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.45</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>22398</td><td>MAGNETS PACK OF 4 SWALLOWS</td><td>12</td><td>2011-11-29 08:07:00</td><td>0.39</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>21746</td><td>SMALL RED RETROSPOT WINDMILL</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.25</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>21747</td><td>SMALL SKULL WINDMILL</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.25</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>22585</td><td>PACK OF 6 BIRDY GIFT TAGS</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.25</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>84228</td><td>HEN HOUSE WITH CHICK STANDING</td><td>12</td><td>2011-11-29 08:07:00</td><td>0.42</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>21894</td><td>POTTING SHED SEED ENVELOPES</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.25</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>23433</td><td>HANGING QUILTED PATCHWORK APPLES</td><td>12</td><td>2011-11-29 08:07:00</td><td>0.83</td><td>13349.0</td><td>United Kingdom</td></tr><tr><td>579256</td><td>23476</td><td>WOODLAND LARGE RED FELT HEART</td><td>12</td><td>2011-11-29 08:07:00</td><td>1.25</td><td>13349.0</td><td>United Kingdom</td></tr></tbody></table></div>

# %% [markdown]
# ## 사용 목적에 따라 모델 서식 지정하기
# - 데이터를 전처리하기 위해서는 우선 <strong>최종 목표</strong>를 검토해야함
# - MLlib의 각 고급 분석 작업을 위한 입력 데이터 구조 관련 요구사항
#   - 대부분의 <strong>분류 및 회귀 알고리즘</strong>의 경우 데이터를 <strong>Double</strong>타입의 컬럼으로 가져와서 레이블을 표시하고 <strong>Vector</strong>타입(밀도가 높거나 희소한)의 컬럼을 사용하여 특징을 나타내야함
#   - <strong>추천 알고리즘</strong>의 경우 데이터를 사용자 컬럼, 영화 또는 서적 등을 나타내는 아이템 컬럼 그리고 사용자 평점 등을 나타내는 등급 컬럼으로 표현해야함
#   - <strong>비지도 학습 알고리즘</strong>의 경우 입력 데이터로 사용할 특징을 <strong>Vector</strong>타입의 컬럼으로 표현해야함
#   - <strong>그래프 분석</strong>의 경우 정점과 에지가 각각 <strong>DataFrame</strong>으로 구성되어야함

# %% [markdown]
# ## 변환자
# - <strong>다양한 방식으로 원시 데이터를 변환</strong>시키는 함수
#   - 주로 데이터 전처리 또는 특징 생성을 위해 사용
#   - 모든 변환자는 입력과 출력의 컬럼 이름을 나타내는 'inputCol'과 'outputCol'을 지정해야함
#     - set 메서드로
# - 새로운 상호작용 변수를 생성(두 개의 다른 변수로)하거나 컬럼을 정규화하거나 모델에 입력하기 위한 변수 타입 변경 등
# - ex) Tokenizer
#   - 문자열을 토큰화하고 주어진 문자로 분할함

# %% [markdown]
# ## 전처리 추정자
# - 수행하려는 변환이 입력 컬럼에 대한 데이터 또는 정보로 초기화되어야 할 때 필요
# - 추정자는 <strong>특정 입력 데이터에 따라 구성되는 변환자</strong>라고 볼 수 있음
# - ex) StandardScaler
#   - 입력 컬럼에 적재된 모든 값의 범위를 고려하여 크기를 조정하여 평균이 0, 분산이 1이 되도록 스케일링 수행

# %% [markdown]
# ## 고수준 변환자
# - 일반적으로 <strong>오류 위험을 최소화</strong>하고, 구현 과정의 세세한 부분보다 <strong>비즈니스 문제에 집중하기 위해</strong> 가능한 한 최상위 수준의 변환자를 사용해야함
# - <strong>RFormula</strong> 같은 고수준 변환자를 사용하면 하나의 변환에서 <strong>여러 가지 변환을 간결하게 지정</strong>할 수 있음
# - 고수준 변환자는 '상위 수준'에서 동작하며 데이터 조작 및 변환을 하나하나 수행하지 않도록 해줌

# %% [markdown]
# ### RFormula
# - R언어에서 빌려온 변환자로서 데이터에 대한 변환을 선언적으로 간단히 지정할 수 있게 해줌
#   - 문법만 이해하면 매우 쉽게 사용 가능
# - 숫자컬럼은 Double타입으로 변환되지만 원-핫 인코딩은 되지 않음
# - 또한 레이블 컬럼이 String인 경우 먼저 StringIndexer를 사용해서 Double타입으로 변환됨
# - [기본 연산자](https://lovetoken.github.io/r/2016/12/06/formula_usage.html)

# %%
from pyspark.ml.feature import RFormula

#모든 변수를 사용(.)하고 value1과 color, value2와 color간의 상호작용을 지정하여 새로운 특징 생성
supervised = RFormula(formula ="lab ~ . + color:value1 + color:value2")
fitted_sup = supervised.fit(simpleDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(fitted_sup.transform(simpleDF).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>lab</th><th>value1</th><th>value2</th><th>features</th><th>label</th></tr></thead><tbody><tr><td>green</td><td>good</td><td>1</td><td>14.386294994851129</td><td>List(0, 10, List(1, 2, 3, 5, 8), List(1.0, 1.0, 14.386294994851129, 1.0, 14.386294994851129))</td><td>1.0</td></tr><tr><td>blue</td><td>bad</td><td>8</td><td>14.386294994851129</td><td>List(0, 10, List(2, 3, 6, 9), List(8.0, 14.386294994851129, 8.0, 14.386294994851129))</td><td>0.0</td></tr><tr><td>blue</td><td>bad</td><td>12</td><td>14.386294994851129</td><td>List(0, 10, List(2, 3, 6, 9), List(12.0, 14.386294994851129, 12.0, 14.386294994851129))</td><td>0.0</td></tr><tr><td>green</td><td>good</td><td>15</td><td>38.97187133755819</td><td>List(0, 10, List(1, 2, 3, 5, 8), List(1.0, 15.0, 38.97187133755819, 15.0, 38.97187133755819))</td><td>1.0</td></tr><tr><td>green</td><td>good</td><td>12</td><td>14.386294994851129</td><td>List(0, 10, List(1, 2, 3, 5, 8), List(1.0, 12.0, 14.386294994851129, 12.0, 14.386294994851129))</td><td>1.0</td></tr><tr><td>green</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>List(0, 10, List(1, 2, 3, 5, 8), List(1.0, 16.0, 14.386294994851129, 16.0, 14.386294994851129))</td><td>0.0</td></tr><tr><td>red</td><td>good</td><td>35</td><td>14.386294994851129</td><td>List(0, 10, List(0, 2, 3, 4, 7), List(1.0, 35.0, 14.386294994851129, 35.0, 14.386294994851129))</td><td>1.0</td></tr><tr><td>red</td><td>bad</td><td>1</td><td>38.97187133755819</td><td>List(0, 10, List(0, 2, 3, 4, 7), List(1.0, 1.0, 38.97187133755819, 1.0, 38.97187133755819))</td><td>0.0</td></tr><tr><td>red</td><td>bad</td><td>2</td><td>14.386294994851129</td><td>List(0, 10, List(0, 2, 3, 4, 7), List(1.0, 2.0, 14.386294994851129, 2.0, 14.386294994851129))</td><td>0.0</td></tr><tr><td>red</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>List(0, 10, List(0, 2, 3, 4, 7), List(1.0, 16.0, 14.386294994851129, 16.0, 14.386294994851129))</td><td>0.0</td></tr></tbody></table></div>

# %% [markdown]
# ### SQL 변환자
# - SQL Transformer를 사용하면 MLlib 변환 기능을 사용할 때처럼 스파크의 방대한 SQL데이터 처리 라이브러리를 활용할 수 있음
#   - 근데 테이블 이름 대신 THIS 키워드를 사용함
# - 사용자는 원시 데이터로부터 현재 상태에 이르기까지의 모든 조작을 SQLTransformer를 사용하여 적용할 수 있음
# - 이를 위해 사용자는 각각의 조작을 변환자로 <strong>버전화</strong>하여 식별 가능
#   - 따라서 변환자만 교체하면 <strong>다양한 파이프라인을 구축하고 테스트 가능</strong>

# %%
from pyspark.ml.feature import SQLTransformer
basicTransformer = SQLTransformer()\
.setStatement('''
select sum(quantity), count(*), customerID
from __THIS__
group by customerID
''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(basicTransformer.transform(sales).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(quantity)</th><th>count(1)</th><th>customerID</th></tr></thead><tbody><tr><td>372</td><td>8</td><td>13094.0</td></tr><tr><td>119</td><td>10</td><td>12493.0</td></tr><tr><td>148</td><td>32</td><td>16212.0</td></tr><tr><td>227</td><td>53</td><td>13121.0</td></tr><tr><td>2138</td><td>23</td><td>16656.0</td></tr><tr><td>13748</td><td>822</td><td>15311.0</td></tr><tr><td>1453</td><td>251</td><td>15750.0</td></tr><tr><td>118</td><td>3</td><td>15898.0</td></tr><tr><td>466</td><td>39</td><td>17659.0</td></tr><tr><td>45</td><td>6</td><td>17879.0</td></tr></tbody></table></div>

# %% [markdown]
# ### 벡터 조합기
# - VectorAssembler는 사용자가 생성하는 거의 모든 <strong>단일 파이프라인</strong>에서 사용하게 될 도구
#   - <strong>모든 특징을 하나의 큰 벡터로 연결</strong>하여 추정자에게 전달하는 기능 제공
#   - <strong>다양한 변환자를 사용하여 여러 가지 조작</strong>을 수행하고 그에 대한 <strong>모든 결과를 모아야하는 경우</strong>에 특히 유용
# - 일반적으로 머신러닝 파이프라인의 마지막 단계에서 사용되고 boolean, double, vector와 같은 다양한 컬럼을 입력으로 사용

# %%
from pyspark.ml.feature import VectorAssembler
va = VectorAssembler().setInputCols(['int1', 'int2','int3'])
va.transform(fakeIntDF).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+----+------------------------------------+
# int1|int2|int3|VectorAssembler_2b6c1e1a3fef__output|
# +----+----+----+------------------------------------+
#    1|   2|   3|                       [1.0,2.0,3.0]|
#    4|   5|   6|                       [4.0,5.0,6.0]|
#    7|   8|   9|                       [7.0,8.0,9.0]|
# +----+----+----+------------------------------------+
#
# </div>

# %% [markdown]
# ## 연속형 특징 처리하기
# - 연속형 특징을 처리하는 데 일반적으로 사용되는 두 개의 변환자가 있음
#   1. 버켓팅
#   2. 스케일링과 정규화

# %%
#일단 모든 변환자는 Double타입에서만 작동
contDF = spark.range(20).selectExpr("cast(id as double)")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 버켓팅
# - <strong>버켓팅 또는 구간화(binning)</strong>에 대한 가장 직접적인 접근법은 <strong>Bucketizer</strong>를 사용하는 것
# - Bucketizer를 사용하면 주어진 연속형 특징을 지정한 버켓으로 분할함
#   - 이때 <strong>어떤 형태로 생성</strong>되어야 하는지 <strong>Double타입 값으로 된 배열이나 리스트로 지정</strong> 가능
#   - 이는 나중에 데이터셋의 특징을 단순화하거나 차후의 해석을 위해 표현을 단순화하려는 경우에 유용
#   - ex) 사람의 체중을 나타내는 컬럼 -> 과체중 / 평균 / 저체중의 세 가지 버켓으로 나누어 활용하는 것이 더 간단한 접근 방법일 수 있음
# - 버켓을 지정하려면 경계를 설정해야하는데 다음 세 가지 요구사항을 충족해야함
#   1. 분할 배열의 <strong>최솟값</strong>은 DF의 최솟값보다 작아야함
#   2. 분할 배열의 <strong>최댓값</strong>은 DF의 최댓값보다 커야함
#   3. 분할 배열은 <strong>최소 세 개 이상의 값</strong>을 지정해서 두 개 이상의 버켓을 만들도록 해야함

# %%
from pyspark.ml.feature import Bucketizer

#근데 가능한 모든 범위를 포함하기 위해 float('inf'), float('-inf')로 지정하는 방법도 있음
bucketBorders = [-1.0, 5.0, 10.0, 250.0, 600.0]
bucketer = Bucketizer().setSplits(bucketBorders).setInputCol('id')
bucketer.transform(contDF).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------------------------------+
#   id|Bucketizer_f5d872a75478__output|
# +----+-------------------------------+
#  0.0|                            0.0|
#  1.0|                            0.0|
#  2.0|                            0.0|
#  3.0|                            0.0|
#  4.0|                            0.0|
#  5.0|                            1.0|
#  6.0|                            1.0|
#  7.0|                            1.0|
#  8.0|                            1.0|
#  9.0|                            1.0|
# 10.0|                            2.0|
# 11.0|                            2.0|
# 12.0|                            2.0|
# 13.0|                            2.0|
# 14.0|                            2.0|
# 15.0|                            2.0|
# 16.0|                            2.0|
# 17.0|                            2.0|
# 18.0|                            2.0|
# 19.0|                            2.0|
# +----+-------------------------------+
#
# </div>

# %%
#위처럼 하드코딩된 값을 기반으로 분할하는 방법 외에도, 백분위수를 기준으로 분할하는 방법도 있음
from pyspark.ml.feature import QuantileDiscretizer
bucketer_q = QuantileDiscretizer().setNumBuckets(5).setInputCol('id').setOutputCol('result')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fitted_bucketer = bucketer_q.fit(contDF)
fitted_bucketer.transform(contDF).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------+
#   id|result|
# +----+------+
#  0.0|   0.0|
#  1.0|   0.0|
#  2.0|   0.0|
#  3.0|   1.0|
#  4.0|   1.0|
#  5.0|   1.0|
#  6.0|   1.0|
#  7.0|   2.0|
#  8.0|   2.0|
#  9.0|   2.0|
# 10.0|   2.0|
# 11.0|   3.0|
# 12.0|   3.0|
# 13.0|   3.0|
# 14.0|   3.0|
# 15.0|   4.0|
# 16.0|   4.0|
# 17.0|   4.0|
# 18.0|   4.0|
# 19.0|   4.0|
# +----+------+
#
# </div>

# %% [markdown]
# ### 스케일링과 정규화
# - 버켓처럼 연속형 변수를 그룹화하는 방법 말고도 일반적으로 사용되는 작업은 데이터의 범위를 스케일링하고 정규화하는 것
# - 이 방법은 서로 다른 단위의 여러 컬럼이 있을 때 적용
#   - 예를 들어, 무게(온스)와 높이(피트)라는 두 컬럼이 있을 때, 무게 값이 훨씬 크기 때문에 알고리즘은 높이의 변화에 덜 민감하게 됨
#   - 따라서 해당 작업을 통해 데이터가 동일한 척도로 구성되어서 서로 합리적인 비교를 할 수 있도록함
# - MLlib는 항상 Vector타입의 컬럼에서 이 작업이 수행됨

# %% [markdown]
# ### StandardScaler
# - 평균이 0이고 표준편차가 1인 분포를 갖도록 데이터를 표준화함
# - withStd플래그는 데이터를 표준편차가 1이 되도록 스케일링 하는 것을 의미
# - withMean플래그는 스케일링을 하기 전에 데이터를 센터링(평균 0)하는 것을 의미
# - 주의: 일반적으로 밀도가 낮은 벡터에서 센터링을 수행하면 밀도가 높은 벡터로 바뀌기 때문에 계산이 오래 걸릴 수 있음

# %%
from pyspark.ml.feature import StandardScaler

sScaler = StandardScaler().setInputCol("features")
fitted_sS = sScaler.fit(scaleDF)
display(fitted_sS.transform(scaleDF))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th><th>StandardScaler_44b4e6ad71c9__output</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(1.1952286093343936, 0.02337622911060922, -0.5976143046671968))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(2.390457218668787, 0.2571385202167014, 0.5976143046671968))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(1.1952286093343936, 0.02337622911060922, -0.5976143046671968))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(2.390457218668787, 0.2571385202167014, 0.5976143046671968))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td><td>List(1, 3, List(), List(3.5856858280031805, 2.3609991401715313, 1.7928429140015902))</td></tr></tbody></table></div>

# %% [markdown]
# ### MinMaxScaler
# - 벡터의 값을 주어진 최솟값에서 최댓값까지의 비례 값으로 스케일링
# - 최솟값을 0으로 지정하고, 최댓값을 1로 지정하면 모든 값이 0에서 1 사이

# %%
from pyspark.ml.feature import MinMaxScaler
minMax = MinMaxScaler().setMin(5).setMax(10).setInputCol('features')
fitted_mM = minMax.fit(scaleDF)
display(fitted_mM.transform(scaleDF))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th><th>MinMaxScaler_d519007e9c8d__output</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(5.0, 5.0, 5.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(7.5, 5.5, 7.5))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(5.0, 5.0, 5.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(7.5, 5.5, 7.5))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td><td>List(1, 3, List(), List(10.0, 10.0, 10.0))</td></tr></tbody></table></div>

# %% [markdown]
# ### MaxAbsScaler
# - 각 값을 해당 컬럼의 최대 절댓값으로 나눠서 데이터의 범위를 조정
# - 따라서 모든 값은 -1에서 1 사이

# %%
from pyspark.ml.feature import MaxAbsScaler
maScaler = MaxAbsScaler().setInputCol("features")
fittedmaScaler = maScaler.fit(scaleDF)
display(fittedmaScaler.transform(scaleDF))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th><th>MaxAbsScaler_16b3dc7958be__output</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(0.3333333333333333, 0.009900990099009903, -0.3333333333333333))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(0.6666666666666666, 0.10891089108910892, 0.3333333333333333))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(0.3333333333333333, 0.009900990099009903, -0.3333333333333333))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(0.6666666666666666, 0.10891089108910892, 0.3333333333333333))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td><td>List(1, 3, List(), List(1.0, 1.0, 1.0))</td></tr></tbody></table></div>

# %% [markdown]
# ### ElementwiseProduct
# - 각 값을 임의의 값으로 조정

# %%
from pyspark.ml.feature import ElementwiseProduct
from pyspark.ml.linalg import Vectors

scaleUpVec = Vectors.dense(10.0, 15.0, 20.0)
scalingUp = ElementwiseProduct().setScalingVec(scaleUpVec)\
.setInputCol("features")

display(scalingUp.transform(scaleDF))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th><th>ElementwiseProduct_8183156d872e__output</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(10.0, 1.5, -20.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(20.0, 16.5, 20.0))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(10.0, 1.5, -20.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(20.0, 16.5, 20.0))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td><td>List(1, 3, List(), List(30.0, 151.5, 60.0))</td></tr></tbody></table></div>

# %% [markdown]
# ### Normalizer
# - 여러 표준 중 하나를 사용하여 다차원 벡터를 스케일링할 수 있음
#   - ex) p=1은 맨해튼 표준 / p=2는 유클리드 표준 등

# %%
from pyspark.ml.feature import Normalizer

manhattanDist = Normalizer().setP(1).setInputCol("features")
display(manhattanDist.transform(scaleDF))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>features</th><th>Normalizer_b63292aa18ea__output</th></tr></thead><tbody><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(0.47619047619047616, 0.047619047619047616, -0.47619047619047616))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(0.48780487804878053, 0.26829268292682934, 0.24390243902439027))</td></tr><tr><td>0</td><td>List(1, 3, List(), List(1.0, 0.1, -1.0))</td><td>List(1, 3, List(), List(0.47619047619047616, 0.047619047619047616, -0.47619047619047616))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(2.0, 1.1, 1.0))</td><td>List(1, 3, List(), List(0.48780487804878053, 0.26829268292682934, 0.24390243902439027))</td></tr><tr><td>1</td><td>List(1, 3, List(), List(3.0, 10.1, 3.0))</td><td>List(1, 3, List(), List(0.18633540372670807, 0.6273291925465838, 0.18633540372670807))</td></tr></tbody></table></div>

# %% [markdown]
# ## 범주형 특징 처리하기
# - 범주형 특징에 대한 가장 일반적인 작업은 인덱싱

# %% [markdown]
# ### StringIndexer
# - 색인을 생성하는 가장 간단한 방법으로, 문자열을 다른 숫자 ID에 매핑
# - 스파크의 StringIndexer는 DF에 첨부된 메타데이터를 생성하여 어떤 입력이 어떤 출력에 해당하는지 지정함
#   - 이렇게 하면 나중에 각 색인값에서 입력값을 다시 가져올 수 있음

# %%
from pyspark.ml.feature import StringIndexer
strInd = StringIndexer().setInputCol("lab").setOutputCol("labelInd")
idxRes = strInd.fit(simpleDF).transform(simpleDF)
display(idxRes.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>lab</th><th>value1</th><th>value2</th><th>labelInd</th></tr></thead><tbody><tr><td>green</td><td>good</td><td>1</td><td>14.386294994851129</td><td>1.0</td></tr><tr><td>blue</td><td>bad</td><td>8</td><td>14.386294994851129</td><td>0.0</td></tr><tr><td>blue</td><td>bad</td><td>12</td><td>14.386294994851129</td><td>0.0</td></tr><tr><td>green</td><td>good</td><td>15</td><td>38.97187133755819</td><td>1.0</td></tr><tr><td>green</td><td>good</td><td>12</td><td>14.386294994851129</td><td>1.0</td></tr><tr><td>green</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>0.0</td></tr><tr><td>red</td><td>good</td><td>35</td><td>14.386294994851129</td><td>1.0</td></tr><tr><td>red</td><td>bad</td><td>1</td><td>38.97187133755819</td><td>0.0</td></tr><tr><td>red</td><td>bad</td><td>2</td><td>14.386294994851129</td><td>0.0</td></tr><tr><td>red</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>0.0</td></tr></tbody></table></div>

# %%
#문자열이 아닌 컬럼에도 적용 가능 (이 경우는 색인 생성 전에 문자열로 변환부터함)
valIndexer = StringIndexer().setInputCol("value1").setOutputCol("valueInd")
display(valIndexer.fit(simpleDF).transform(simpleDF).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>lab</th><th>value1</th><th>value2</th><th>valueInd</th></tr></thead><tbody><tr><td>green</td><td>good</td><td>1</td><td>14.386294994851129</td><td>0.0</td></tr><tr><td>blue</td><td>bad</td><td>8</td><td>14.386294994851129</td><td>7.0</td></tr><tr><td>blue</td><td>bad</td><td>12</td><td>14.386294994851129</td><td>1.0</td></tr><tr><td>green</td><td>good</td><td>15</td><td>38.97187133755819</td><td>3.0</td></tr><tr><td>green</td><td>good</td><td>12</td><td>14.386294994851129</td><td>1.0</td></tr><tr><td>green</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>2.0</td></tr><tr><td>red</td><td>good</td><td>35</td><td>14.386294994851129</td><td>5.0</td></tr><tr><td>red</td><td>bad</td><td>1</td><td>38.97187133755819</td><td>0.0</td></tr><tr><td>red</td><td>bad</td><td>2</td><td>14.386294994851129</td><td>4.0</td></tr><tr><td>red</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>2.0</td></tr></tbody></table></div>

# %%
#만약 학습 과정에서 관측되지 않았던 값인 경우 해당 로우 전체를 아예 건너뛰도록 하는 옵션
valIndexer.setHandleInvalid('skip')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: StringIndexer_e65c4549bb78</div>

# %% [markdown]
# ### 색인된 값을 텍스트로 변환하기
# - MLlib분류 모델은 색인된 값을 사용하여 예측하고, 결과를 원래 범주로 다시 변환하는데 유용함
# - IndexToString으로 변환된 값을 기존 값으로 다시 매핑 가능

# %%
from pyspark.ml.feature import IndexToString 
labelReverse = IndexToString().setInputCol("labelInd")
display(labelReverse.transform(idxRes).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>lab</th><th>value1</th><th>value2</th><th>labelInd</th><th>IndexToString_8a6d53090a19__output</th></tr></thead><tbody><tr><td>green</td><td>good</td><td>1</td><td>14.386294994851129</td><td>1.0</td><td>good</td></tr><tr><td>blue</td><td>bad</td><td>8</td><td>14.386294994851129</td><td>0.0</td><td>bad</td></tr><tr><td>blue</td><td>bad</td><td>12</td><td>14.386294994851129</td><td>0.0</td><td>bad</td></tr><tr><td>green</td><td>good</td><td>15</td><td>38.97187133755819</td><td>1.0</td><td>good</td></tr><tr><td>green</td><td>good</td><td>12</td><td>14.386294994851129</td><td>1.0</td><td>good</td></tr><tr><td>green</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>0.0</td><td>bad</td></tr><tr><td>red</td><td>good</td><td>35</td><td>14.386294994851129</td><td>1.0</td><td>good</td></tr><tr><td>red</td><td>bad</td><td>1</td><td>38.97187133755819</td><td>0.0</td><td>bad</td></tr><tr><td>red</td><td>bad</td><td>2</td><td>14.386294994851129</td><td>0.0</td><td>bad</td></tr><tr><td>red</td><td>bad</td><td>16</td><td>14.386294994851129</td><td>0.0</td><td>bad</td></tr></tbody></table></div>

# %% [markdown]
# ### 벡터 인덱싱하기
# - VectorIndexer는 벡터 내 존재하는 범주형 변수를 대상으로 하는 유용한 도구
#   - 입력 벡터 내에 존재하는 범주형 데이터를 자동으로 찾아서 0부터 시작하는 카테고리 색인을 사용하여 범주형 특징으로 변환
# - maxCategories 값으로 고유한 값 개수에 따른 범주형 변수 변환 가능
#   - 사용자가 사전에 데이터 내 가장 큰 카테고리가 무엇인지, 해당 카테고리 내 고유한 값이 몇 개인지 알고 있는 경우 유용하게 사용 가능
#   - 주의: 연속형인데 고유 값이 적으면 의도하지 않게 범주형 변수로 잘못 변환될 수 있음

# %%
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.linalg import Vectors
idxIn = spark.createDataFrame([
  (Vectors.dense(1,2,3),1),
  (Vectors.dense(2,5,6),2),
  (Vectors.dense(1,8,9),3)
]).toDF("features", "label")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indxr = VectorIndexer().setInputCol("features").setOutputCol("idxed").setMaxCategories(2)
display(indxr.fit(idxIn).transform(idxIn))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</th><th>idxed</th></tr></thead><tbody><tr><td>List(1, 3, List(), List(1.0, 2.0, 3.0))</td><td>1</td><td>List(1, 3, List(), List(0.0, 2.0, 3.0))</td></tr><tr><td>List(1, 3, List(), List(2.0, 5.0, 6.0))</td><td>2</td><td>List(1, 3, List(), List(1.0, 5.0, 6.0))</td></tr><tr><td>List(1, 3, List(), List(1.0, 8.0, 9.0))</td><td>3</td><td>List(1, 3, List(), List(0.0, 8.0, 9.0))</td></tr></tbody></table></div>

# %% [markdown]
# ### 원-핫 인코딩
# -  인덱싱이 언제나 옳은 방법은 아님
#   - ex) 색상컬럼 인덱싱: 파랑:1, 녹색:2
#     -  녹색 > 파랑 인 것처럼 보이는 수학적 모양을 제공하기 때문에 올바르지 않음
# - 따라서 고유한 값을 1또는0(불리언 타입)의 벡터 구성 요소로 변환하는 OneHotEncoder사용
#   - 더는 정렬되지 않으므로 다운스트림모델(ex 선형모델)이 처리하기 쉬움

# %%
from pyspark.ml.feature import OneHotEncoder, StringIndexer
indxr2 = StringIndexer().setInputCol("color").setOutputCol("colorInd")
colorLab = indxr2.fit(simpleDF).transform(simpleDF.select("color"))
ohe = OneHotEncoder().setInputCol("colorInd").fit(colorLab)
display(ohe.transform(colorLab).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>color</th><th>colorInd</th><th>OneHotEncoder_5cf00af0ea1f__output</th></tr></thead><tbody><tr><td>green</td><td>1.0</td><td>List(0, 2, List(1), List(1.0))</td></tr><tr><td>blue</td><td>2.0</td><td>List(0, 2, List(), List())</td></tr><tr><td>blue</td><td>2.0</td><td>List(0, 2, List(), List())</td></tr><tr><td>green</td><td>1.0</td><td>List(0, 2, List(1), List(1.0))</td></tr><tr><td>green</td><td>1.0</td><td>List(0, 2, List(1), List(1.0))</td></tr><tr><td>green</td><td>1.0</td><td>List(0, 2, List(1), List(1.0))</td></tr><tr><td>red</td><td>0.0</td><td>List(0, 2, List(0), List(1.0))</td></tr><tr><td>red</td><td>0.0</td><td>List(0, 2, List(0), List(1.0))</td></tr><tr><td>red</td><td>0.0</td><td>List(0, 2, List(0), List(1.0))</td></tr><tr><td>red</td><td>0.0</td><td>List(0, 2, List(0), List(1.0))</td></tr></tbody></table></div>

# %% [markdown]
# ## 텍스트 데이터 변환자

# %% [markdown]
# ## 특징 조작하기

# %% [markdown]
# ## 특징 선택

# %% [markdown]
# ## 고급 주제
