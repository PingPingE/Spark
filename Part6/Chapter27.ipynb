# %% [markdown]
# # 회귀

# %% [markdown]
# ## MLlib에서 제공하는 회귀 모델(3.0.1)
# [doc](https://spark.apache.org/docs/3.0.1/ml-classification-regression.html)
# - Linear regression
# - Generalized linear regression
# - Available families
# - Decision tree regression
# - Random forest regression
# - Gradient-boosted tree regression
# - Survival regression
# - Isotonic regression
# - Factorization machines regressor

# %% [markdown]
# ### 모델 확장성
# - MLlib에서 제공하는 회귀 모델은 모두 큰 규모의 데이터셋으로 확장 가능
# - 회귀 모델별 확장성(최대 특징 수)
#   - 선형 회귀: 1천만개
#   - 일반화 선형 회귀: 4,096개
#   - 의사결정트리: 1,000개
#   - 랜덤 포레스트: 10,000개
#   - 그래디언트 부스티드 트리: 1,000개
#   - 생존 회귀: 1천만개

# %%
path= 
df = spark.read.load(path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## 선형 회귀

# %%
from pyspark.ml.regression import LinearRegresion
lr = LinearRegression().setMaxIter(10).setRegParam(0.3).setElasticNetParam(0.8)
print lr.explainParams()
lrModel = lr.fit(df)

# %%
summary = lrModel.summay
summary.residuals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
print summary.totalIterations
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
print summary.rootMeanSquaredError
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## 랜덤 포레스트와 그래디언트 부스티드 트리

# %%
from pyspark.ml.regression import RandomForestRegressor,GBTRegressor
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
gbt = GBTRegressor()
gbt.explainParams()
gbtModel = gbt.fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
